# %%
import pandas as pd
import math
import numpy as np
from matplotlib import pyplot as plt

# %%
def connection_trim_ag(filename):
    rois=pd.read_csv(filename)
    cnx_check = [col for col in rois if 'cnx' in col]
    num_electrodes=len(rois[cnx_check].columns)
    for elect in range(num_electrodes):
        print cnx_check[elect]
        connections=len(rois[rois[cnx_check[elect]]=='excitatory'].index)
        inhib_cons=len(rois[rois[cnx_check[elect]]=='inhibitory'].index)
        tested=len(rois.index)    
        print 'counted '+str(connections)+' excitatory connections out of '+str(tested)+ ' tested'
        print 'counted '+str(inhib_cons)+' inhibitory connections out of '+str(tested)+ ' tested'
        dists=np.zeros((tested,tested))
        count_test=0
        passedROIs=pd.DataFrame()
        skip=[]
        for test_i in rois.index:
            uhoh=0
            neighbors=[test_i]
            for i in rois.index:
                x_dif=rois['X_mm'][i]-rois['X_mm'][test_i]
                y_dif=rois['Y_mm'][i]-rois['Y_mm'][test_i]
                z_dif=rois['Z_mm'][i]-rois['Z_mm'][test_i]
                xyz_dif=math.sqrt(x_dif**2+y_dif**2+z_dif**2)
                dists[test_i,i]=xyz_dif
                if test_i!=i and xyz_dif < 10 and i >= count_test:            
                    print 'look out! '+ str(test_i) + ' and '+ str(i) + ' are only '+str(xyz_dif)+ ' microns apart'
                    if rois[cnx_check[elect]][test_i]==rois[cnx_check[elect]][i]:
                        uhoh+=1
                        neighbors.append(i)
                        skip.append(i)
                        print '   both ROIs marked '+ rois[cnx_check[elect]][test_i]

            
   
    
            if test_i not in skip:
                passedROIs=passedROIs.append(rois[test_i:test_i+1])
            else: 
                tested-=1
            count_test+=1
        connections=len(passedROIs[passedROIs[cnx_check[elect]]=='excitatory'].index)
        tested=len(passedROIs.index)
        inhib_cons=len(rois[rois[cnx_check[elect]]=='inhibitory'].index)
        print 'updated: counted '+str(connections)+' excitatory connections out of '+str(tested)+ ' tested'
        print 'updated: counted '+str(inhib_cons)+' inhibitory connections out of '+str(tested)+ ' tested'
    return passedROIs

# %%
def read_connections_csv(): ## old
    key=pd.read_csv('connections_key.csv', converters={'HS0_class': str, 'HS1_class':str, 'HS0_reporter':str, 'HS1_reporter': str})
    all_dfs={}
    everything=pd.DataFrame()
    for file_i in key.index:
        df_i=connection_trim_ag(key['filename'][file_i]+'.csv')
        ##all_dfs[file_i] = pd.read_csv(key['filename'][file_i]+'.csv')
        all_dfs[file_i]=df_i
        if(key['HS0_angle'][file_i]!='NaN'):
            angle=key['HS0_angle'][file_i]
            centerx=key['HS0_x'][file_i]
            centery=key['HS0_y'][file_i]
            df_i=rotate_rois(df_i,centerx,centery,angle)
        elif(key['HS1_angle'][file_i]!='NaN'):
            angle=key['HS1_angle'][file_i]
            centerx=key['HS1_x'][file_i]
            centery=key['HS1_y'][file_i]            
            df_i=rotate_rois(df_i,centerx,centery,angle)
        else:
            print "no info for rotate"
        df_i['presynapticCre']=key['presynaptic_driver'][file_i]
        df_i['presynaptic_effector']=key['presynaptic_effector'][file_i]
        df_i['HS_class']=key['HS0_class'][file_i]+key['HS1_class'][file_i]
        df_i['HS_reporter']=key['HS0_reporter'][file_i]+key['HS1_reporter'][file_i]
        all_dfs[file_i]=df_i
        everything=everything.append(df_i)
    everything['electrode_x_cnx']=everything['electrode_0_cnx'].fillna('')+everything['electrode_1_cnx'].fillna('')
    everything['electrode_x']=everything.electrode_0.fillna(0)+everything.electrode_1.fillna(0)

    return everything

# %%
def rotate_rois(df,cellx,celly,angle):
    angle=angle*np.pi/180
    df['X_center']=df['X_mm']-cellx
    df['Y_center']=(df['Y_mm']-celly)*-1
    df['X_rotate']=df['X_center']*np.cos(angle)-df['Y_center']*np.sin(angle)
    df['Y_rotate']=df['X_center']*np.sin(angle)+df['Y_center']*np.cos(angle)
    return df

# %%
def read_connections_csv_hsrows():
    key=pd.read_csv('connections_key.csv', converters={'HS0_class': str, 'HS1_class':str, 'HS0_reporter':str, 'HS1_reporter': str})
    
    everything=pd.DataFrame()
    for file_i in key.index:
        df_i=connection_trim_ag(key['filename'][file_i]+'.csv')
        cnx_check=[col for col in df_i if 'cnx' in col]
    
        for cnx in cnx_check:
            electrode_id=cnx[10:11]
            df_electrode=df_i
            df_electrode['electrode_id']=electrode_id
            old_d_name='electrode_'+electrode_id
            old_cnx_name='electrode_'+electrode_id+'_cnx'
            old_z_name='z_electrode_'+electrode_id
            df_electrode=df_electrode.rename(columns={old_d_name: 'xy_dist', old_cnx_name: 'cnx',old_z_name: 'z_dist'})
            HS_angle_name='HS'+electrode_id+'_angle'
            HS_x_name='HS'+electrode_id+'_x'
            HS_y_name='HS'+electrode_id+'_y'
            HS_class_name='HS'+electrode_id+'_class'
            HS_reporter_name='HS'+electrode_id+'_reporter'
            if(key[HS_angle_name][file_i]!='NaN'):
                angle=key[HS_angle_name][file_i]
                centerx=key[HS_x_name][file_i]
                centery=key[HS_y_name][file_i]
                df_electrode=rotate_rois(df_electrode,centerx,centery,angle)
            df_electrode['presynapticCre']=key['presynaptic_driver'][file_i]
            df_electrode['presynaptic_effector']=key['presynaptic_effector'][file_i]
            df_electrode['HS_class']=key[HS_class_name][file_i]
            df_electrode['HS_reporter']=key[HS_reporter_name][file_i]
            everything=everything.append(df_electrode)
    return everything

# %%
testdual=connection_trim_ag('2017_09_15_exp2_CB_connections.csv')
# Out:
# electrode_1_cnx
# counted 2 excitatory connections out of 39 tested
# counted 0 inhibitory connections out of 39 tested
# look out! 6 and 7 are only 3.35117911898 microns apart
#    both ROIs marked no cnx
# look out! 13 and 32 are only 3.35117911898 microns apart
#    both ROIs marked tbd
# look out! 29 and 34 are only 4.78053862766 microns apart
#    both ROIs marked no cnx
# updated: counted 2 excitatory connections out of 36 tested
# updated: counted 0 inhibitory connections out of 36 tested
# electrode_2_cnx
# counted 1 excitatory connections out of 39 tested
# counted 0 inhibitory connections out of 39 tested
# look out! 6 and 7 are only 3.35117911898 microns apart
#    both ROIs marked tbd
# look out! 13 and 32 are only 3.35117911898 microns apart
#    both ROIs marked no cnx
# 22    86.300196          no cnx    NaN     5.0
# 23   170.176286          no cnx    NaN     5.0
# 24    12.878481             tbd    NaN     5.0
# 25    53.076811          no cnx    NaN     5.0
# 26    79.052078          no cnx    NaN     5.0
# 27   118.510557          no cnx    NaN     5.0
# 28    14.556483             tbd    NaN     5.0
# 29    39.334218          no cnx    NaN     5.0
# 30   114.546708          no cnx    NaN     5.0
# 31   126.039614          no cnx    NaN     5.0
# 33   147.586446          no cnx    NaN     5.0
# 35    83.349999          no cnx    NaN     5.0
# 36    71.154172          no cnx    NaN     5.0
# 37   189.232793          no cnx    NaN     5.0
# 38    59.042979          no cnx    NaN     5.0
#
#                                                sweeps  z_electrode_1  \
# 0   [array([387, 397, 407, 417, 427, 437, 447, 457...            NaN
# 1   [array([148, 157, 166, 175, 184, 193, 202, 211...            NaN
# 2   [array([386, 396, 406, 416, 426, 436, 446, 456...            NaN
# 3   [[146, 155, 164, 173, 182, 191, 200, 209, 218,...            NaN
# 4   [array([154, 163, 172, 181, 190, 199, 208, 217...            NaN
# 5    [[70, 78, 86, 94, 102, 110, 118, 126, 134, 142]]            NaN
# 6          [[27, 30, 33, 36, 39, 42, 45, 48, 51, 54]]            NaN
# 8   [array([150, 159, 168, 177, 186, 195, 204, 213...            NaN
# 9   [[152, 161, 170, 179, 188, 197, 206, 215, 224,...            NaN
# 10  [array([ 72,  80,  88,  96, 104, 112, 120, 128...            NaN
# 11   [[73, 81, 89, 97, 105, 113, 121, 129, 137, 145]]            NaN
# 12  [array([389, 399, 409, 419, 429, 439, 449, 459...            NaN
# 13    [[66, 74, 82, 90, 98, 106, 114, 122, 130, 138]]            NaN
# 14  [array([302, 311, 320, 329, 338, 347, 356, 365...            NaN
# 15  [array([395, 405, 415, 425, 435, 445, 455, 465...            NaN
# 16  [array([304, 313, 322, 331, 340, 349, 358, 367...            NaN
# 17  [array([392, 402, 412, 422, 432, 442, 452, 462...            NaN
# 18  [array([300, 309, 318, 327, 336, 345, 354, 363...            NaN
# 19  [array([149, 158, 167, 176, 185, 194, 203, 212...            NaN
# 20  [array([391, 401, 411, 421, 431, 441, 451, 461...            NaN
# 21  [array([393, 403, 413, 423, 433, 443, 453, 463...            NaN
# 22  [array([ 71,  79,  87,  95, 103, 111, 119, 127...            NaN
# 23  [array([394, 404, 414, 424, 434, 444, 454, 464...            NaN
# 24  [[147, 156, 165, 174, 183, 192, 201, 210, 219,...            NaN
# 25  [array([ 68,  76,  84,  92, 100, 108, 116, 124...            NaN
# 26  [array([151, 160, 169, 178, 187, 196, 205, 214...            NaN
# 27  [array([301, 310, 319, 328, 337, 346, 355, 364...            NaN
# 28  [[297, 306, 315, 324, 333, 342, 351, 360, 369,...            NaN
# 29  [array([298, 307, 316, 325, 334, 343, 352, 361...            NaN
# 30  [array([388, 398, 408, 418, 428, 438, 448, 458...            NaN
# 31  [array([299, 308, 317, 326, 335, 344, 353, 362...            NaN
# 33  [array([303, 312, 321, 330, 339, 348, 357, 366...            NaN
# 35  [array([28, 31, 34, 37, 40, 43, 46, 49, 52, 55])]            NaN
# 36  [array([ 69,  77,  85,  93, 101, 109, 117, 125...            NaN
# 37  [array([390, 400, 410, 420, 430, 440, 450, 460...            NaN
# 38  [[296, 305, 314, 323, 332, 341, 350, 359, 368,...            NaN
#
#     z_electrode_2
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 33            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN

# %%
cnx_row_all=read_connections_csv_hsrows()
cnx_row_all
# Out:
# electrode_0_cnx
# counted 0 excitatory connections out of 12 tested
# counted 2 inhibitory connections out of 12 tested
# look out! 0 and 2 are only 6.02100489952 microns apart
#    both ROIs marked no cnx
# look out! 1 and 4 are only 6.02100489952 microns apart
#    both ROIs marked inhibitory
# look out! 5 and 8 are only 6.02100489952 microns apart
#    both ROIs marked no cnx
# look out! 6 and 10 are only 6.02100489952 microns apart
#    both ROIs marked no cnx
# look out! 7 and 9 are only 6.02100489952 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 7 tested
# updated: counted 2 inhibitory connections out of 7 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 12 tested
# counted 0 inhibitory connections out of 12 tested
# look out! 1 and 11 are only 2.21576172004 microns apart
#    both ROIs marked tbd
# look out! 2 and 7 are only 2.21576172004 microns apart
#    both ROIs marked tbd
# look out! 3 and 5 are only 2.21576172004 microns apart
#    both ROIs marked tbd
# look out! 4 and 6 are only 2.21576172004 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 8 tested
# updated: counted 0 inhibitory connections out of 8 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 10 tested
# counted 2 inhibitory connections out of 10 tested
# updated: counted 0 excitatory connections out of 10 tested
# updated: counted 2 inhibitory connections out of 10 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 19 tested
# counted 2 inhibitory connections out of 19 tested
# look out! 7 and 14 are only 9.22368593518 microns apart
# updated: counted 0 excitatory connections out of 19 tested
# updated: counted 2 inhibitory connections out of 19 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 24 tested
# counted 2 inhibitory connections out of 24 tested
# updated: counted 0 excitatory connections out of 24 tested
# updated: counted 2 inhibitory connections out of 24 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 49 tested
# counted 0 inhibitory connections out of 49 tested
# look out! 1 and 9 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 4 and 38 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 5 and 40 are only 9.72872550749 microns apart
#    both ROIs marked no cnx
# look out! 5 and 41 are only 8.97875826604 microns apart
#    both ROIs marked no cnx
# look out! 8 and 28 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 11 and 12 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 15 and 29 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 16 and 48 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 18 and 27 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 20 and 46 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 21 and 39 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 23 and 25 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 35 and 36 are only 2.3 microns apart
#    both ROIs marked no cnx
# look out! 40 and 41 are only 2.3 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 36 tested
# updated: counted 0 inhibitory connections out of 36 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 58 tested
# counted 0 inhibitory connections out of 58 tested
# look out! 42 and 57 are only 9.79129117662 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 57 tested
# updated: counted 0 inhibitory connections out of 57 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 42 tested
# counted 0 inhibitory connections out of 42 tested
# look out! 1 and 16 are only 6.19553746703 microns apart
#    both ROIs marked no cnx
# look out! 2 and 30 are only 9.49361156069 microns apart
#    both ROIs marked no cnx
# look out! 6 and 35 are only 9.70396137049 microns apart
#    both ROIs marked no cnx
# look out! 8 and 41 are only 6.70850802359 microns apart
#    both ROIs marked no cnx
# look out! 9 and 12 are only 2.98456041157 microns apart
#    both ROIs marked no cnx
# look out! 9 and 31 are only 9.71463994796 microns apart
#    both ROIs marked no cnx
# look out! 10 and 19 are only 9.97453983947 microns apart
#    both ROIs marked no cnx
# look out! 12 and 31 are only 8.17325445832 microns apart
#    both ROIs marked no cnx
# look out! 14 and 25 are only 3.83236341968 microns apart
#    both ROIs marked no cnx
# look out! 15 and 40 are only 9.93413213653 microns apart
#    both ROIs marked no cnx
# look out! 25 and 30 are only 8.97113823742 microns apart
#    both ROIs marked no cnx
# look out! 29 and 35 are only 9.22205807986 microns apart
#    both ROIs marked no cnx
# look out! 31 and 36 are only 5.36004441203 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 32 tested
# updated: counted 0 inhibitory connections out of 32 tested
# electrode_1_cnx
# counted 12 excitatory connections out of 70 tested
# counted 0 inhibitory connections out of 70 tested
# look out! 2 and 39 are only 5.13679117747 microns apart
#    both ROIs marked excitatory
# look out! 4 and 49 are only 3.91795253756 microns apart
#    both ROIs marked no cnx
# look out! 16 and 34 are only 8.04415385162 microns apart
#    both ROIs marked excitatory
# look out! 16 and 45 are only 4.19939765165 microns apart
#    both ROIs marked excitatory
# look out! 22 and 67 are only 9.76650099915 microns apart
#    both ROIs marked no cnx
# look out! 29 and 69 are only 3.16830693475 microns apart
#    both ROIs marked no cnx
# look out! 34 and 45 are only 9.69590276359 microns apart
#    both ROIs marked excitatory
# look out! 48 and 63 are only 9.09384735902 microns apart
#    both ROIs marked no cnx
# look out! 55 and 56 are only 1.62842994423 microns apart
#    both ROIs marked excitatory
# updated: counted 8 excitatory connections out of 62 tested
# updated: counted 0 inhibitory connections out of 62 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 61 tested
# counted 0 inhibitory connections out of 61 tested
# updated: counted 0 excitatory connections out of 61 tested
# updated: counted 0 inhibitory connections out of 61 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 30 tested
# counted 0 inhibitory connections out of 30 tested
# look out! 1 and 8 are only 9.99796625899 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 29 tested
# updated: counted 0 inhibitory connections out of 29 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 70 tested
# counted 0 inhibitory connections out of 70 tested
# updated: counted 0 excitatory connections out of 70 tested
# updated: counted 0 inhibitory connections out of 70 tested
# electrode_0_cnx
# counted 3 excitatory connections out of 94 tested
# counted 0 inhibitory connections out of 94 tested
# look out! 26 and 27 are only 8.88227048647 microns apart
#    both ROIs marked excitatory
# look out! 35 and 38 are only 9.5591555572 microns apart
#    both ROIs marked no cnx
# updated: counted 2 excitatory connections out of 92 tested
# updated: counted 0 inhibitory connections out of 92 tested
# electrode_0_cnx
# counted 1 excitatory connections out of 20 tested
# counted 0 inhibitory connections out of 20 tested
# updated: counted 1 excitatory connections out of 20 tested
# updated: counted 0 inhibitory connections out of 20 tested
# electrode_0_cnx
# counted 8 excitatory connections out of 28 tested
# counted 0 inhibitory connections out of 28 tested
# look out! 6 and 11 are only 9.24408801139 microns apart
# updated: counted 8 excitatory connections out of 28 tested
# updated: counted 0 inhibitory connections out of 28 tested
# electrode_1_cnx
# counted 2 excitatory connections out of 24 tested
# counted 0 inhibitory connections out of 24 tested
# updated: counted 2 excitatory connections out of 24 tested
# updated: counted 0 inhibitory connections out of 24 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 33 tested
# counted 0 inhibitory connections out of 33 tested
# updated: counted 0 excitatory connections out of 33 tested
# updated: counted 0 inhibitory connections out of 33 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 7 tested
# counted 0 inhibitory connections out of 7 tested
# updated: counted 0 excitatory connections out of 7 tested
# updated: counted 0 inhibitory connections out of 7 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 12 tested
# counted 0 inhibitory connections out of 12 tested
# look out! 0 and 11 are only 1.12699423246 microns apart
#    both ROIs marked tbd
# look out! 1 and 2 are only 1.12699423246 microns apart
#    both ROIs marked tbd
# look out! 3 and 7 are only 1.12699423246 microns apart
#    both ROIs marked no cnx
# look out! 4 and 8 are only 1.12699423246 microns apart
#    both ROIs marked no cnx
# look out! 5 and 6 are only 1.12699423246 microns apart
#    both ROIs marked tbd
# look out! 9 and 10 are only 1.12699423246 microns apart
#    both ROIs marked tbd
# updated: counted 0 excitatory connections out of 6 tested
# updated: counted 0 inhibitory connections out of 6 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 6 tested
# counted 0 inhibitory connections out of 6 tested
# updated: counted 0 excitatory connections out of 6 tested
# updated: counted 0 inhibitory connections out of 6 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 24 tested
# counted 0 inhibitory connections out of 24 tested
# updated: counted 0 excitatory connections out of 24 tested
# updated: counted 0 inhibitory connections out of 24 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 27 tested
# counted 0 inhibitory connections out of 27 tested
# look out! 6 and 10 are only 5.3 microns apart
#    both ROIs marked no cnx
# look out! 8 and 16 are only 5.3 microns apart
#    both ROIs marked no cnx
# look out! 9 and 21 are only 5.3 microns apart
#    both ROIs marked no cnx
# look out! 12 and 23 are only 5.3 microns apart
#    both ROIs marked no cnx
# look out! 14 and 15 are only 5.3 microns apart
#    both ROIs marked no cnx
# look out! 17 and 19 are only 5.3 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 21 tested
# updated: counted 0 inhibitory connections out of 21 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 21 tested
# counted 0 inhibitory connections out of 21 tested
# look out! 0 and 11 are only 7.12364584875 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 20 tested
# updated: counted 0 inhibitory connections out of 20 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 23 tested
# counted 0 inhibitory connections out of 23 tested
# updated: counted 0 excitatory connections out of 23 tested
# updated: counted 0 inhibitory connections out of 23 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 4 tested
# counted 0 inhibitory connections out of 4 tested
# updated: counted 0 excitatory connections out of 4 tested
# updated: counted 0 inhibitory connections out of 4 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 15 tested
# counted 0 inhibitory connections out of 15 tested
# updated: counted 0 excitatory connections out of 15 tested
# updated: counted 0 inhibitory connections out of 15 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 14 tested
# counted 0 inhibitory connections out of 14 tested
# look out! 0 and 7 are only 4.5 microns apart
#    both ROIs marked no cnx
# look out! 2 and 13 are only 4.5 microns apart
#    both ROIs marked no cnx
# look out! 8 and 10 are only 4.5 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 11 tested
# updated: counted 0 inhibitory connections out of 11 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 41 tested
# counted 0 inhibitory connections out of 41 tested
# updated: counted 0 excitatory connections out of 41 tested
# updated: counted 0 inhibitory connections out of 41 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 89 tested
# counted 0 inhibitory connections out of 89 tested
# updated: counted 0 excitatory connections out of 89 tested
# updated: counted 0 inhibitory connections out of 89 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 24 tested
# counted 0 inhibitory connections out of 24 tested
# look out! 20 and 21 are only 7.67493640091 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 23 tested
# updated: counted 0 inhibitory connections out of 23 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 64 tested
# counted 0 inhibitory connections out of 64 tested
# look out! 2 and 38 are only 9.07901418606 microns apart
#    both ROIs marked no cnx
# look out! 9 and 41 are only 7.50568853888 microns apart
#    both ROIs marked no cnx
# look out! 17 and 24 are only 6.52805479789 microns apart
#    both ROIs marked no cnx
# look out! 22 and 42 are only 1.66836581377 microns apart
#    both ROIs marked no cnx
# look out! 24 and 60 are only 9.77500531059 microns apart
#    both ROIs marked no cnx
# look out! 43 and 60 are only 4.31565161455 microns apart
#    both ROIs marked no cnx
# look out! 45 and 52 are only 9.69274402769 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 58 tested
# updated: counted 0 inhibitory connections out of 58 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 34 tested
# counted 0 inhibitory connections out of 34 tested
# look out! 0 and 24 are only 9.56144191519 microns apart
#    both ROIs marked no cnx
# look out! 1 and 31 are only 9.26592167379 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 32 tested
# updated: counted 0 inhibitory connections out of 32 tested
# electrode_0_cnx
# counted 2 excitatory connections out of 47 tested
# counted 0 inhibitory connections out of 47 tested
# look out! 12 and 18 are only 5.33225374094 microns apart
# updated: counted 2 excitatory connections out of 47 tested
# updated: counted 0 inhibitory connections out of 47 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 29 tested
# counted 0 inhibitory connections out of 29 tested
# look out! 1 and 16 are only 7.21942454395 microns apart
#    both ROIs marked no cnx
# updated: counted 0 excitatory connections out of 28 tested
# updated: counted 0 inhibitory connections out of 28 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 5 tested
# counted 1 inhibitory connections out of 5 tested
# updated: counted 0 excitatory connections out of 5 tested
# updated: counted 1 inhibitory connections out of 5 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 6 tested
# counted 0 inhibitory connections out of 6 tested
# updated: counted 0 excitatory connections out of 6 tested
# updated: counted 0 inhibitory connections out of 6 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 46 tested
# counted 4 inhibitory connections out of 46 tested
# updated: counted 0 excitatory connections out of 46 tested
# updated: counted 4 inhibitory connections out of 46 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 22 tested
# counted 4 inhibitory connections out of 22 tested
# updated: counted 0 excitatory connections out of 22 tested
# updated: counted 4 inhibitory connections out of 22 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 13 tested
# counted 5 inhibitory connections out of 13 tested
# updated: counted 0 excitatory connections out of 13 tested
# updated: counted 5 inhibitory connections out of 13 tested
# electrode_1_cnx
# counted 4 excitatory connections out of 59 tested
# counted 0 inhibitory connections out of 59 tested
# look out! 3 and 28 are only 1.63041354895 microns apart
#    both ROIs marked excitatory
# look out! 9 and 10 are only 4.66005364776 microns apart
#    both ROIs marked no cnx
# look out! 19 and 41 are only 1.92990197311 microns apart
#    both ROIs marked excitatory
# updated: counted 2 excitatory connections out of 56 tested
# updated: counted 0 inhibitory connections out of 56 tested
# electrode_0_cnx
# counted 0 excitatory connections out of 48 tested
# counted 2 inhibitory connections out of 48 tested
# updated: counted 0 excitatory connections out of 48 tested
# updated: counted 2 inhibitory connections out of 48 tested
# electrode_1_cnx
# counted 0 excitatory connections out of 18 tested
# counted 0 inhibitory connections out of 18 tested
# updated: counted 0 excitatory connections out of 18 tested
# updated: counted 0 inhibitory connections out of 18 tested
# electrode_1_cnx
# counted 2 excitatory connections out of 46 tested
# counted 0 inhibitory connections out of 46 tested
# look out! 0 and 1 are only 1.05973588184 microns apart
#    both ROIs marked tbd
# look out! 11 and 16 are only 9.66918261342 microns apart
# look out! 15 and 27 are only 7.73679778385 microns apart
#    both ROIs marked no cnx
# look out! 17 and 34 are only 7.84790269542 microns apart
#    both ROIs marked no cnx
# look out! 18 and 21 are only 8.37794779631 microns apart
#    both ROIs marked no cnx
# look out! 21 and 40 are only 4.19901540454 microns apart
#    both ROIs marked no cnx
# look out! 39 and 45 are only 5.12631832357 microns apart
#    both ROIs marked no cnx
# updated: counted 2 excitatory connections out of 40 tested
# updated: counted 0 inhibitory connections out of 40 tested
# electrode_1_cnx
# counted 2 excitatory connections out of 39 tested
# counted 0 inhibitory connections out of 39 tested
# look out! 6 and 7 are only 3.35117911898 microns apart
#    both ROIs marked no cnx
# look out! 13 and 32 are only 3.35117911898 microns apart
#    both ROIs marked tbd
# look out! 29 and 34 are only 4.78053862766 microns apart
#    both ROIs marked no cnx
# updated: counted 2 excitatory connections out of 36 tested
# updated: counted 0 inhibitory connections out of 36 tested
# electrode_2_cnx
# counted 1 excitatory connections out of 39 tested
# counted 0 inhibitory connections out of 39 tested
# look out! 6 and 7 are only 3.35117911898 microns apart
#    both ROIs marked tbd
# look out! 13 and 32 are only 3.35117911898 microns apart
#    both ROIs marked no cnx
# look out! 29 and 34 are only 4.78053862766 microns apart
#    both ROIs marked no cnx
# updated: counted 1 excitatory connections out of 36 tested
# updated: counted 0 inhibitory connections out of 36 tested
#    HS_class HS_reporter                      Image               MP_ID  \
# 0       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_4']
# 1       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_2']
# 3       pyr         neg  TSeries-09012017-1015-001   ['TSeries_101_1']
# 5       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_5']
# 6       pyr         neg  TSeries-09012017-1015-001    ['TSeries_51_3']
# 7       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_1']
# 11      pyr         neg  TSeries-09012017-1015-001   ['TSeries_101_2']
# 0     inter         neg  ZSeries-09012017-1015-022   ['TSeries_107_1']
# 1     inter         neg  ZSeries-09012017-1015-022    ['TSeries_67_1']
# 2     inter         neg  ZSeries-09012017-1015-022    ['TSeries_27_4']
# 3     inter         neg  ZSeries-09012017-1015-022    ['TSeries_27_2']
# 4     inter         neg  ZSeries-09012017-1015-022    ['TSeries_27_3']
# 8     inter         neg  ZSeries-09012017-1015-022   ['TSeries_107_4']
# 9     inter         neg  ZSeries-09012017-1015-022   ['TSeries_107_3']
# 10    inter         neg  ZSeries-09012017-1015-022   ['TSeries_107_2']
# 0       pyr         neg  TSeries-09012017-1015-021    ['TSeries_21_1']
# 1       pyr         neg  TSeries-09012017-1015-021     ['TSeries_1_1']
# 2       pyr         neg  TSeries-09012017-1015-021    ['TSeries_41_1']
# 3       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_3']
# 4       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_2']
# 5       pyr         neg  TSeries-09012017-1015-021     ['TSeries_1_2']
# 6       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_4']
# 7       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_1']
# 8       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_5']
# 9       pyr         neg  TSeries-09012017-1015-021    ['TSeries_21_2']
# 0       pyr         neg  TSeries-09012017-1015-027    ['TSeries_27_4']
# 1       pyr         neg  TSeries-09012017-1015-027    ['TSeries_27_2']
# 2       pyr         neg  TSeries-09012017-1015-027   ['TSeries_161_2']
# 3       pyr         neg  TSeries-09012017-1015-027   ['TSeries_107_1']
# 4       pyr         neg  TSeries-09012017-1015-027    ['TSeries_67_2']
# ..      ...         ...                        ...                 ...
# 6       pyr         pos  TSeries-09152017-1301-026    ['TSeries_26_2']
# 8       pyr         pos  TSeries-09152017-1301-026   ['TSeries_146
pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_4']
# 1       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_2']
# 3       pyr         neg  TSeries-09012017-1015-001   ['TSeries_101_1']
# 5       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_5']
# 6       pyr         neg  TSeries-09012017-1015-001    ['TSeries_51_3']
# 7       pyr         neg  TSeries-09012017-1015-001     ['TSeries_1_1']
# 11      pyr         neg  TSeries-09012017-1015-001   ['TSeries_101_2']
# 0       pyr         neg  TSeries-09012017-1015-021    ['TSeries_21_1']
# 1       pyr         neg  TSeries-09012017-1015-021     ['TSeries_1_1']
# 2       pyr         neg  TSeries-09012017-1015-021    ['TSeries_41_1']
# 3       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_3']
# 4       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_2']
# 5       pyr         neg  TSeries-09012017-1015-021     ['TSeries_1_2']
# 6       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_4']
# 7       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_1']
# 8       pyr         neg  TSeries-09012017-1015-021    ['TSeries_51_5']
# 9       pyr         neg  TSeries-09012017-1015-021    ['TSeries_21_2']
# 0       pyr         neg  TSeries-09012017-1015-027    ['TSeries_27_4']
# 1       pyr         neg  TSeries-09012017-1015-027    ['TSeries_27_2']
# 2       pyr         neg  TSeries-09012017-1015-027   ['TSeries_161_2']
# 3       pyr         neg  TSeries-09012017-1015-027   ['TSeries_107_1']
# 4       pyr         neg  TSeries-09012017-1015-027    ['TSeries_67_2']
# 5       pyr         neg  TSeries-09012017-1015-027   ['TSeries_127_3']
# 6       pyr         neg  TSeries-09012017-1015-027    ['TSeries_87_1']
# 7       pyr         neg  TSeries-09012017-1015-027   ['TSeries_127_1']
# 8       pyr         neg  TSeries-09012017-1015-027    ['TSeries_67_1']
# 9       pyr         neg  TSeries-09012017-1015-027   ['TSeries_107_2']
# 10      pyr         neg  TSeries-09012017-1015-027    ['TSeries_27_1']
# 11      pyr         neg  TSeries-09012017-1015-027   ['TSeries_161_1']
# 12      pyr         neg  TSeries-09012017-1015-027   ['TSeries_161_3']
# ..      ...         ...                        ...                 ...
# 6       pyr         pos  TSeries-09152017-1301-026    ['TSeries_26_2']
# 8       pyr         pos  TSeries-09152017-1301-026   ['TSeries_146_5']
# 9       pyr         pos  TSeries-09152017-1301-026   ['TSeries_146_7']
# 10      pyr         pos  TSeries-09152017-1301-026    ['TSeries_66_7']
# 11      pyr         pos  TSeries-09152017-1301-026    ['TSeries_66_8']
# 12      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_4']
# 13      pyr         pos  TSeries-09152017-1301-026    ['TSeries_66_1']
# 14      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_7']
# 15      pyr         pos  TSeries-09152017-1301-026  ['TSeries_386_10']
# 16      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_9']
# 17      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_7']
# 18      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_5']
# 19      pyr         pos  TSeries-09152017-1301-026   ['TSeries_146_4']
# 20      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_6']
# 21      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_8']
# 22      pyr         pos  TSeries-09152017-1301-026    ['TSeries_66_6']
# 23      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_9']
# 24      pyr         pos  TSeries-09152017-1301-026   ['TSeries_146_2']
# 25      pyr         pos  TSeries-09152017-1301-026    ['TSeries_66_3']
# 26      pyr         pos  TSeries-09152017-1301-026   ['TSeries_146_6']
# 27      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_6']
# 28      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_2']
# 29      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_3']
# 30      pyr         pos  TSeries-09152017-1301-026   ['TSeries_386_3']
# 31      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296_4']
# 33      pyr         pos  TSeries-09152017-1301-026   ['TSeries_296
# 24          24   12.007047 -4165.472953    293   11.322514   -4.667421
# 25          25   11.746544 -4165.733456    293   47.088748  -51.763485
# 26          26  -60.503982 -4237.983982     98   -0.290888  -50.875430
# 27          27   48.268329 -4129.211671    391  113.787308 -108.239030
# 28          28  -11.920565 -4189.400565    229  -14.074409    8.347330
# 29          29    2.060320 -4175.419680    266   31.304561  -39.282463
# 30          30   -9.650923 -4187.130923    235   80.852267 -114.141212
# 31          31   17.462990 -4160.017010    308  106.531403 -124.826521
# 33          33  101.348298 -4076.131702    534  147.374467 -107.291174
# 35          35   28.570998 -4148.909002    338   78.214104  -78.303470
# 36          36  -65.266804 -4242.746804     85  -63.804121   28.330397
# 37          37  -24.816629 -4202.296629    194  127.098937 -187.600098
# 38          38  -54.100183 -4231.580183    115  -16.930195  -23.642830
#
#         ...       electrode_id  notes  presynapticCre  presynaptic_effector  \
# 0       ...                  0    NaN            GAD2                 Ai136
# 1       ...                  0    NaN            GAD2                 Ai136
# 3       ...                  0    NaN            GAD2                 Ai136
# 5       ...                  0    NaN            GAD2                 Ai136
# 6       ...                  0    NaN            GAD2                 Ai136
# 7       ...                  0    NaN            GAD2                 Ai136
# 11      ...                  0    NaN            GAD2                 Ai136
# 0       ...                  0    NaN            GAD2                 Ai136
# 1       ...                  0    NaN            GAD2                 Ai136
# 2       ...                  0    NaN            GAD2                 Ai136
# 3       ...                  0    NaN            GAD2                 Ai136
# 4       ...                  0    NaN            GAD2                 Ai136
# 5       ...                  0    NaN            GAD2                 Ai136
# 6       ...                  0    NaN            GAD2                 Ai136
# 7       ...                  0    NaN            GAD2                 Ai136
# 8       ...                  0    NaN            GAD2                 Ai136
# 9       ...                  0    NaN            GAD2                 Ai136
# 0       ...                  0    NaN            GAD2                 Ai136
# 1       ...                  0    NaN            GAD2                 Ai136
# 2       ...                  0    NaN            GAD2                 Ai136
# 3       ...                  0    NaN            GAD2                 Ai136
# 4       ...                  0    NaN            GAD2                 Ai136
# 5       ...                  0    NaN            GAD2                 Ai136
# 6       ...                  0    NaN            GAD2                 Ai136
# 7       ...                  0    NaN            GAD2                 Ai136
# 8       ...                  0    NaN            GAD2                 Ai136
# 9       ...                  0    NaN            GAD2                 Ai136
# 10      ...                  0    NaN            GAD2                 Ai136
# 11      ...                  0    NaN            GAD2                 Ai136
# 12      ...                  0    NaN            GAD2                 Ai136
# ..      ...                ...    ...             ...                   ...
# 6       ...                  2    NaN         Slc17a7                 Ai136
# 8       ...                  2    NaN         Slc17a7                 Ai136
# 9       ...                  2    NaN         Slc17a7                 Ai136
# 10      ...                  2    NaN         Slc17a7                 Ai136
# 11      ...                  2    NaN         Slc17a7                 Ai136
# 12      ...                  2    NaN         Slc17a7                 Ai136
# 13      ...                  2    NaN         Slc17a7                 Ai136
# 14      ...                  2    NaN         Slc17a7                 Ai136
# 15      ...                  2    NaN         Slc17a7                 Ai136
# 16      ...                  2    NaN         Slc17a7                 Ai136
# 17      ...                  2    NaN         Slc17a7                 Ai136
# 7                    ['TSeries_308_5']           7  -97.919131 -1145.519131
# 8                    ['TSeries_118_7']           8  -56.028954 -1103.628954
# 10                   ['TSeries_188_1']          10   -4.813416 -1052.413416
# 11  ['TSeries_27_12', 'TSeries_58_12']          11    4.217583 -1043.382417
# 13                  ['TSeries_308_10']          13  -28.155686 -1075.755686
# 14                   ['TSeries_188_9']          14   54.365231  -993.234769
# 15    ['TSeries_27_3', 'TSeries_58_3']          15   24.424925 -1023.175075
# 16    ['TSeries_27_6', 'TSeries_58_6']          16  -58.088391 -1105.688391
# 17                   ['TSeries_308_9']          17   37.518178 -1010.081822
# 18                  ['TSeries_118_10']          18  -87.061659 -1134.661659
# 19                   ['TSeries_188_5']          19 -102.722802 -1150.322802
# 20    ['TSeries_27_4', 'TSeries_58_4']          20   -1.796507 -1049.396507
# 21  ['TSeries_27_11', 'TSeries_58_11']          21 -102.833221 -1150.433221
# 22                   ['TSeries_188_4']          22    5.530819 -1042.069181
# 23                   ['TSeries_118_1']          23   34.663524 -1012.936476
# 24                   ['TSeries_188_2']          24   13.469418 -1034.130582
# 26                  ['TSeries_308_11']          26 -102.249276 -1149.849276
# 30                   ['TSeries_308_8']          30  -59.428954 -1107.028954
# 31                   ['TSeries_308_2']          31   16.589144 -1031.010856
# 32                   ['TSeries_188_6']          32  -43.063029 -1090.663029
# 33                   ['TSeries_308_6']          33 -115.720837 -1163.320837
# 34                   ['TSeries_188_7']          34 -104.647311 -1152.247311
# 35    ['TSeries_27_5', 'TSeries_58_5']          35  -37.640484 -1085.240484
# ..                                 ...         ...         ...          ...
# 6                     ['TSeries_26_2']           6   -1.523448 -4179.003448
# 8                    ['TSeries_146_5']           8  -86.807003 -4264.287003
# 9                    ['TSeries_146_7']           9  -10.267583 -4187.747583
# 10                    ['TSeries_66_7']          10   41.130098 -4136.349902
# 11                    ['TSeries_66_8']          11  -70.243051 -4247.723051
# 12                   ['TSeries_386_4']          12   -8.940031 -4186.420031
# 13                    ['TSeries_66_1']          13  -42.044318 -4219.524318
# 14                   ['TSeries_296_7']          14   67.462425 -4110.017575
# 15                  ['TSeries_386_10']          15  106.935438 -4070.544562
# 16                   ['TSeries_296_9']          16  111.300792 -4066.179208
# 17                   ['TSeries_386_7']          17   27.789412 -4149.690588
# 18                   ['TSeries_296_5']          18   29.311197 -4148.168803
# 19                   ['TSeries_146_4']          19  -50.551488 -4228.031488
# 20                   ['TSeries_386_6']          20  115.940075 -4061.539925
# 21                   ['TSeries_386_8']          21   67.125461 -4110.354539
# 22                    ['TSeries_66_6']          22   -5.551839 -4183.031839
# 23                   ['TSeries_386_9']          23   85.608664 -4091.871336
# 24                   ['TSeries_146_2']          24   12.007047 -4165.472953
# 25                    ['TSeries_66_3']          25   11.746544 -4165.733456
# 26                   ['TSeries_146_6']          26  -60.503982 -4237.983982
# 27                   ['TSeries_296_6']          27   48.268329 -4129.211671
# 28                   ['TSeries_296_2']          28  -11.920565 -4189.400565
# 29                   ['TSeries_296_3']          29    2.060320 -4175.419680
# 26         Slc17a7                 Ai136    5.0
# 27         Slc17a7                 Ai136    5.0
# 28         Slc17a7                 Ai136    5.0
# 29         Slc17a7                 Ai136    5.0
# 30         Slc17a7                 Ai136    5.0
# 31         Slc17a7                 Ai136    5.0
# 33         Slc17a7                 Ai136    5.0
# 35         Slc17a7                 Ai136    5.0
# 36         Slc17a7                 Ai136    5.0
# 37         Slc17a7                 Ai136    5.0
# 38         Slc17a7                 Ai136    5.0
#
#                                                sweeps     xy_dist  z_dist  \
# 0   [array([308, 320, 332, 344, 356, 368, 380, 392...   49.520507   17.64
# 1                  [array([119, 131, 143, 155, 167])]   66.727156    1.25
# 2   [array([319, 331, 343, 355, 367, 379, 391, 403...   47.339777   17.64
# 3   [array([195, 207, 219, 231, 243, 255, 267, 279...   34.825049   19.03
# 4   [array([35, 47, 59, 71, 83]), array([ 66,  78,...   57.720295    1.25
# 5   [array([178, 179, 180, 181, 182, 183, 184, 185...   64.512219    9.16
# 6   [array([199, 211, 223, 235, 247, 259, 271, 283...   42.977799   19.03
# 7   [array([312, 324, 336, 348, 360, 372, 384, 396...  104.455172   17.64
# 8                  [array([124, 136, 148, 160, 172])]   74.784160    1.25
# 10  [array([188, 200, 212, 224, 236, 248, 260, 272...   66.070063   19.03
# 11  [array([38, 50, 62, 74, 86]), array([ 69,  81,...   23.813707    1.25
# 13  [array([317, 329, 341, 353, 365, 377, 389, 401...   98.297120   17.64
# 14  [array([196, 208, 220, 232, 244, 256, 268, 280...   80.473108   19.03
# 15  [array([29, 41, 53, 65, 77]), array([ 60,  72,...   25.743787    1.25
# 16  [array([32, 44, 56, 68, 80]), array([ 63,  75,...   58.420484    1.25
# 17  [array([316, 328, 340, 352, 364, 376, 388, 400...  171.605462   17.64
# 18                 [array([127, 139, 151, 163, 175])]   90.964525    1.25
# 19  [array([192, 204, 216, 228, 240, 252, 264, 276...  132.166189   19.03
# 20  [array([30, 42, 54, 66, 78]), array([ 61,  73,...    6.074931    1.25
# 21  [array([37, 49, 61, 73, 85]), array([ 68,  80,...  118.280980    1.25
# 22  [array([191, 203, 215, 227, 239, 251, 263, 275...   50.245883   19.03
# 23                 [array([118, 130, 142, 154, 166])]   93.723026    1.25
# 24  [array([189, 201, 213, 225, 237, 249, 261, 273...   65.215821   19.03
# 26  [array([318, 330, 342, 354, 366, 378, 390, 402...  161.032710   17.64
# 30  [array([315, 327, 339, 351, 363, 375, 387, 399...   68.625649   17.64
# 31  [array([309, 321, 333, 345, 357, 369, 381, 393...   36.312904   17.64
# 32  [array([193, 205, 217, 229, 241, 253, 265, 277...   46.504246   19.03
# 33  [array([313, 325, 337, 349, 361, 373, 385, 397...  185.838922   17.64
# 34  [array([194, 206, 218, 230, 242, 254, 266, 278...  106.824680   19.03
# 35  [array([31, 43, 55, 67, 79]), array([ 62,  74,...   41.772328    1.25
# ..                                                ...         ...     ...
# 6          [[27, 30, 33, 36, 39, 42, 45, 48, 51, 54]]    1.564199     NaN
# 8   [array([150, 159, 168, 177, 186, 195, 204, 213...   86.810868     NaN
# 9   [[152, 161, 170, 179, 188, 197, 206, 215, 224,...   45.184229     NaN
# 10  [array([ 72,  80,  88,  96, 104, 112, 120, 128...   79.971461     NaN
# 11   [[73, 81, 89, 97, 105, 113, 121, 129, 137, 145]]   84.269131     NaN
# 12  [array([389, 399, 409, 419, 429, 439, 449, 459...  144.037578     NaN
# 13    [[66, 74, 82, 90, 98, 106, 114, 122, 130, 138]]   54.366382     NaN
# 14  [array([302, 311, 320, 329, 338, 347, 356, 365...  116.874708     NaN
# 15  [array([395, 405, 415, 425, 435, 445, 455, 465...  182.608560     NaN
# 16  [array([304, 313, 322, 331, 340, 349, 358, 367...  147.234242     NaN
# 17  [array([392, 402, 412, 422, 432, 442, 452, 462...  188.707061     NaN
# 18  [array([300, 309, 318, 327, 336, 345, 354, 363...  156.735555     NaN
# 19  [array([149, 158, 167, 176, 185, 194, 203, 212...   56.912971     NaN
# 20  [array([391, 401, 411, 421, 431, 441, 451, 461...  257.158044     NaN
# 21  [array([393, 403, 413, 423, 433, 443, 453, 463...  146.951816     NaN
# 22  [array([ 71,  79,  87,  95, 103, 111, 119, 127...   86.300196     NaN
# 23  [array([394, 404, 414, 424, 434, 444, 454, 464...  170.176286     NaN
# 24  [[147, 156, 165, 174, 183, 192, 201, 210, 219,...   12.878481     NaN
# 25  [array([ 68,  76,  84,  92, 100, 108, 116, 124...   53.076811     NaN
# 26  [array([151, 160, 169, 178, 187, 196, 205, 214...   79.052078     NaN
# 27  [array([301, 310, 319, 328, 337, 346, 355, 364...  118.510557     NaN
# 28  [[297, 306, 315, 324, 333, 342, 351, 360, 369,...   14.556483     NaN
# 29  [array([298, 307, 316, 325, 334, 343, 352, 361...   39.334218     NaN
# 30  [array([388, 398, 408, 418, 428, 438, 448, 458...  114.546708     NaN
# 31  [array([299, 308, 317, 326, 335, 344, 353, 362...  126.039614     NaN
# 33  [array([303, 312, 321, 330, 339, 348, 357, 366...  147.586446     NaN
# 35  [array([28, 31, 34, 37, 40, 43, 46, 49, 52, 55])]   83.349999     NaN
# 36  [array([ 69,  77,  85,  93, 101, 109, 117, 125...   71.154172     NaN
# 37  [array([390, 400, 410, 420, 430, 440, 450, 460...  189.232793     NaN
# 38  [[296, 305, 314, 323, 332, 341, 350, 359, 368,...   59.042979     NaN
#
#    z_electrode_1 z_electrode_2
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# 5            NaN           NaN
# 6            NaN           NaN
# 7            NaN           NaN
# 8            NaN           NaN
# 10           NaN           NaN
# 11           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN
# 17           NaN           NaN
# 18           NaN           NaN
# 19           NaN           NaN
# 20           NaN           NaN
# 21           NaN           NaN
# 22           NaN           NaN
# 23           NaN           NaN
# 24           NaN           NaN
# 26           NaN           NaN
# 30           NaN           NaN
# 31           NaN           NaN
# 32           NaN           NaN
# 33           NaN           NaN
# 34           NaN           NaN
# 35           NaN           NaN
# ..           ...           ...
# 6            NaN           NaN
# 8            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
# 11           NaN           NaN
# 12           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN
# 17           NaN           NaN
# 18           NaN           NaN
# 19           NaN           NaN
# 20           NaN           NaN
# 21           NaN           NaN
# 22           NaN           NaN
# 23           NaN           NaN
# 24           NaN           NaN
# 25           NaN           NaN
# 26           NaN           NaN
# 27           NaN           NaN
# 28           NaN           NaN
# 29           NaN           NaN
# 30           NaN           NaN
# 31           NaN           NaN
# 33           NaN           NaN
# 35           NaN           NaN
# 36           NaN           NaN
# 37           NaN           NaN
# 38           NaN           NaN
#
# [635 rows x 29 columns]

# %%
df=pyr

plt.hist(df[df['cnx']=='no cnx']['xy_dist'],bins=range(0,450,10),label='no_cnx',alpha=0.5)
plt.hist(df[df['cnx']=='excitatory']['xy_dist'],bins=range(0,450,10),label='excitatory_cnx')
plt.hist(df[df['cnx']=='tbd']['xy_dist'],bins=range(0,450,10),label='direct',alpha=0.5)


plt.xlabel('x_dist')
plt.ylabel('# of occurences')

plt.legend()
plt.show()

# %%
df=L5EtoE

plt.hist(df[df['cnx']=='no cnx']['xy_dist'],bins=range(0,450,10),label='no_cnx',alpha=0.5)
plt.hist(df[df['cnx']=='excitatory']['xy_dist'],bins=range(0,450,10),label='excitatory_cnx')
plt.hist(df[df['cnx']=='tbd']['xy_dist'],bins=range(0,450,10),label='direct',alpha=0.5)


plt.xlabel('xy_dist')
plt.ylabel('# of occurences')

plt.legend()
plt.show()

# %%
plt.scatter(pyr[pyr['cnx']=='no cnx']['xy_dist'],pyr[pyr['cnx']=='no cnx']['z_dist'], label='no cnx')

#plt.scatter(pyr[pyr['cnx']=='tbd']['xy_dist'],pyr[pyr['cnx']=='tbd']['z_dist'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['xy_dist'], pyr[pyr['cnx']=='excitatory']['z_dist'],label='excitatory')
plt.xlabel('xy distance')
plt.ylabel('z distance')
plt.legend()
plt.show()

# %%
##plt.scatter(pyr[pyr['cnx']=='tbd']['X_rotate'],pyr[pyr['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['X_rotate'],pyr[pyr['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['X_rotate'], pyr[pyr['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.legend()
plt.show()

# %%
##plt.scatter(pyr[pyr['cnx']=='tbd']['X_rotate'],pyr[pyr['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['X_rotate'],pyr[pyr['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['X_rotate'], pyr[pyr['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.legend()
plt.show()

# %%
plt.scatter(pyr[pyr['cnx']=='no cnx']['X_rotate'],pyr[pyr['cnx']=='no cnx']['Y_rotate'], label='no cnx')

plt.scatter(pyr[pyr['cnx']=='tbd']['X_rotate'],pyr[pyr['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['X_rotate'],pyr[pyr['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['X_rotate'], pyr[pyr['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.xlabel('lateral distance')
plt.ylabel('translaminar distance')
plt.legend()
plt.show()

# %%
df=Slc2e[Slc2e['HS_reporter']=='neg']

plt.scatter(df[df['cnx']=='no cnx']['X_rotate'],df[df['cnx']=='no cnx']['Y_rotate'], label='no cnx')

plt.scatter(df[df['cnx']=='tbd']['X_rotate'],df[df['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(df[df['cnx']=='inhibitory']['X_rotate'],df[df['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(df[df['cnx']=='excitatory']['X_rotate'], df[df['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.xlabel('lateral distance')
plt.ylabel('translaminar distance')
plt.legend()
plt.show()

# %%
df=Slc2e[Slc2e['HS_reporter']=='pos']

plt.scatter(df[df['cnx']=='no cnx']['X_rotate'],df[df['cnx']=='no cnx']['Y_rotate'], label='no cnx')

plt.scatter(df[df['cnx']=='tbd']['X_rotate'],df[df['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(df[df['cnx']=='inhibitory']['X_rotate'],df[df['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(df[df['cnx']=='excitatory']['X_rotate'], df[df['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.xlabel('lateral distance')
plt.ylabel('translaminar distance')
plt.legend()
plt.show()

# %%
df=L5EtoE

plt.scatter(df[df['cnx']=='no cnx']['X_rotate'],df[df['cnx']=='no cnx']['Y_rotate'], label='no cnx')

plt.scatter(df[df['cnx']=='tbd']['X_rotate'],df[df['cnx']=='tbd']['Y_rotate'], label='direct')
plt.scatter(df[df['cnx']=='inhibitory']['X_rotate'],df[df['cnx']=='inhibitory']['Y_rotate'],label='inhibitory')
plt.scatter(df[df['cnx']=='excitatory']['X_rotate'], df[df['cnx']=='excitatory']['Y_rotate'],label='excitatory')
plt.xlabel('lateral distance')
plt.ylabel('translaminar distance')
plt.legend()
plt.show()

# %%
plt.scatter(pyr[pyr['cnx']=='no cnx']['xy_dist'],pyr[pyr['cnx']=='no cnx']['z_dist'], label='no cnx')

#plt.scatter(pyr[pyr['cnx']=='tbd']['xy_dist'],pyr[pyr['cnx']=='tbd']['z_dist'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['xy_dist'], pyr[pyr['cnx']=='excitatory']['z_dist'],label='excitatory')
plt.xlabel('xy distance')
plt.ylabel('z distance')
plt.legend()
plt.show()

# %%
plt.scatter(pyr[pyr['cnx']=='no cnx']['xy_dist'],pyr[pyr['cnx']=='no cnx']['z_dist'], label='no cnx')

#plt.scatter(pyr[pyr['cnx']=='tbd']['xy_dist'],pyr[pyr['cnx']=='tbd']['z_dist'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['xy_dist'], pyr[pyr['cnx']=='excitatory']['z_dist'],label='excitatory')
plt.xlabel('xy distance')
plt.ylabel('z distance')
plt.legend()
plt.show()

# %%
#plt.scatter(pyr[pyr['cnx']=='no cnx']['xy_dist'],pyr[pyr['cnx']=='no cnx']['z_dist'], label='no cnx')

#plt.scatter(pyr[pyr['cnx']=='tbd']['xy_dist'],pyr[pyr['cnx']=='tbd']['z_dist'], label='direct')
plt.scatter(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],label='inhibitory')
plt.scatter(pyr[pyr['cnx']=='excitatory']['xy_dist'], pyr[pyr['cnx']=='excitatory']['z_dist'],label='excitatory')
m,b=np.polyfit(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],1)
print m
print b
plt.xlabel('xy distance')
plt.ylabel('z distance')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-200e3851ddae> in <module>()
#       4 plt.scatter(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],label='inhibitory')
#       5 plt.scatter(pyr[pyr['cnx']=='excitatory']['xy_dist'], pyr[pyr['cnx']=='excitatory']['z_dist'],label='excitatory')
# ----> 6 m,b=np.polyfit(pyr[pyr['cnx']=='inhibitory']['xy_dist'],pyr[pyr['cnx']=='inhibitory']['z_dist'],1)
#       7 print m
#       8 print b
#
# /Users/travishage/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.pyc in polyfit(x, y, deg, rcond, full, w, cov)
#     583     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     584     lhs /= scale
# --> 585     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     586     c = (c.T/scale).T  # broadcast scale coefficients
#     587
#
# /Users/travishage/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in lstsq(a, b, rcond)
#    1963         work = zeros((lwork,), t)
#    1964         results = lapack_routine(m, n, n_rhs, a, m, bstar, ldb, s, rcond,
# -> 1965                                  0, work, lwork, iwork, 0)
#    1966     if results['info'] > 0:
#    1967         raise LinAlgError('SVD did not converge in Linear Least Squares')
#
# ValueError: On entry to DGELSD parameter number 6 had an illegal value

# %%
def exp_plots_group(exp_df):
    groups=exp_df.groupby('cnx')
    for name, group in groups:
        plt.scatter(group.X_rotate, group.Y_rotate, label=name, alpha=0.3)
    plt.xlabel('x location')
    plt.ylabel('y location')
    plt.legend()
    plt.show()

# %%
exp_plots_group(pyr)
